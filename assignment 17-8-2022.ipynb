# %%
import pandas as pd
df = pd.read_csv(r"E:\cloudiee data science\FlightDelays.csv")
df
# Out:
#       CRS_DEP_TIME CARRIER  DEP_TIME DEST  DISTANCE    FL_DATE  FL_NUM ORIGIN  \
# 0             1455      OH      1455  JFK       184   1/1/2004    5935    BWI
# 1             1640      DH      1640  JFK       213   1/1/2004    6155    DCA
# 2             1245      DH      1245  LGA       229   1/1/2004    7208    IAD
# 3             1715      DH      1709  LGA       229   1/1/2004    7215    IAD
# 4             1039      DH      1035  LGA       229   1/1/2004    7792    IAD
# ...            ...     ...       ...  ...       ...        ...     ...    ...
# 2196           645      RU       644  EWR       199  1/31/2004    2761    DCA
# 2197          1700      RU      1653  EWR       213  1/31/2004    2497    IAD
# 2198          1600      RU      1558  EWR       199  1/31/2004    2361    DCA
# 2199          1359      RU      1403  EWR       199  1/31/2004    2216    DCA
# 2200          1730      RU      1736  EWR       199  1/31/2004    2097    DCA
#
# ...

# %%
df['DAY_WEEK'].unique()
#lets consider 6,7 are weekends
# Out:
# array([4, 5, 6, 7, 1, 2, 3], dtype=int64)

# %% [markdown]
# # flight delayed in a weekday

# %%
a = df.loc[(df['Flight Status']!='ontime') & (df['DAY_WEEK']!=6) & (df['DAY_WEEK']!=7) ]
a
# Out:
#       CRS_DEP_TIME CARRIER  DEP_TIME DEST  DISTANCE    FL_DATE  FL_NUM ORIGIN  \
# 53            1455      DH      1531  LGA       229   1/2/2004    7211    IAD
# 56            1039      DH      1236  LGA       229   1/2/2004    7792    IAD
# 62            2120      DH      2305  JFK       228   1/2/2004    7814    IAD
# 96            1245      DH      1350  EWR       213   1/2/2004    7303    IAD
# 97            1430      DH      1512  EWR       213   1/2/2004    7307    IAD
# ...            ...     ...       ...  ...       ...        ...     ...    ...
# 2143          1900      RU      1856  EWR       213  1/30/2004    2385    IAD
# 2145          1359      RU      1359  EWR       199  1/30/2004    2216    DCA
# 2146          1525      RU      1601  EWR       199  1/30/2004    2261    DCA
# 2149          1500      RU      1456  EWR       213  1/30/2004    2156    IAD
# 2150           700      RU       659  EWR       213  1/30/2004    2855    IAD
#
# ...

# %% [markdown]
# # average distance , total distance, and count all delayed flights on friday

# %%
avg = df['DISTANCE'].mean()
avg
# Out:
# 211.87142208087232

# %%
total = df['DISTANCE'].sum()
total
# Out:
# 466329

# %%
b = df.loc[(df['Flight Status']!='ontime') & (df['DAY_WEEK']==5)]
len(b)
# Out:
# 75

# %% [markdown]
# # how many flights were on time on weekdays and weekends

# %%
weekdays = df.loc[(df['Flight Status']=='ontime') & (df['DAY_WEEK']!=6) & (df['DAY_WEEK']!=7) ]
len(weekdays)
# Out:
# 1362

# %%
weekends = df.loc[(df['Flight Status']=='ontime') & ((df['DAY_WEEK']==6) | (df['DAY_WEEK']==7)) ]
len(weekends)
# Out:
# 411

# %% [markdown]
# # no of flights on each destination across all weekdays

# %%
d = df.loc[(df['DAY_WEEK']!=6) & (df['DAY_WEEK']!=7)]
d['DEST'].value_counts()
# Out:
# LGA    919
# EWR    507
# JFK    272
# Name: DEST, dtype: int64

# %% [markdown]
# # no of days the weather was bad on weekdays

# %%
e = df.loc[(df['DAY_WEEK']!=6) & (df['DAY_WEEK']!=7) & (df['Weather']==1)]
len(e)
# Out:
# 30
